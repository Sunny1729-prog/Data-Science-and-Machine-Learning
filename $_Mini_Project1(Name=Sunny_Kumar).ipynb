# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunny1729-prog/Data-Science-and-Machine-Learning/blob/main/%24_Mini_Project1(Name%3DSunny_Kumar).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install --upgrade pandas
# !pip install --upgrade pandas-datareader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#Importings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import pandas_datareader.data as web
from datetime import datetime

# %% [markdown]
# ##Reading the data from yahoo wabsite

# %%
stock_list=['AAPL','MSFT', 'GOOG', 'AMZN']
end_date = datetime.now()
start_date = datetime(end_date.year-1,end_date.month,end_date.day)
print(start_date)
print(end_date)
# Out:
# 2021-06-23 00:00:00
# 2022-06-23 10:50:57.341925

# %%
#Amazon data
amzn_data=web.DataReader(name='AMZN',data_source='yahoo',start=start_date,end=end_date)
amzn_data
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-06-23  176.050003  174.160004  175.250000  175.190994  56266000.0
# 2021-06-24  176.242996  171.542496  175.382004  172.453995  76640000.0
# 2021-06-25  173.240997  169.709000  173.199997  170.072998  78820000.0
# 2021-06-28  172.399994  170.675507  170.800003  172.194504  44856000.0
# 2021-06-29  172.801498  171.151505  171.940994  172.406998  41968000.0
# ...                ...         ...         ...         ...         ...
# 2022-06-15  109.059998  103.529999  103.860001  107.669998  85011100.0
# 2022-06-16  104.580002  102.010002  104.470001  103.660004  82186300.0
# 2022-06-17  106.980003  102.510002  102.800003  106.220001  99399000.0
# 2022-06-21  111.629997  103.559998  108.199997  108.680000  70901200.0
# 2022-06-22  112.129997  107.019997  107.430000  108.949997  59942500.0
#
#              Adj Close
# Date
# 2021-06-23  175.190994
# 2021-06-24  172.453995
# 2021-06-25  170.072998
# ...

# %%
#Google data
goog_data=web.DataReader(name='GOOG',data_source='yahoo',start=start_date,end=end_date)
goog_data
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2021-06-23  2555.919922  2525.040039  2531.000000  2529.229980   984700
# 2021-06-24  2550.709961  2539.199951  2541.070068  2545.639893   946700
# 2021-06-25  2550.100098  2528.879883  2539.139893  2539.899902  1674200
# 2021-06-28  2546.739990  2519.476074  2540.000000  2536.389893  1405500
# 2021-06-29  2540.000000  2508.739990  2535.449951  2520.370117  1047500
# ...                 ...          ...          ...          ...      ...
# 2022-06-15  2241.260010  2162.375000  2177.989990  2207.810059  1659600
# 2022-06-16  2185.810059  2115.850098  2162.989990  2132.719971  1765700
# 2022-06-17  2184.989990  2112.571045  2130.699951  2157.310059  2163500
# 2022-06-21  2253.459961  2185.870117  2194.040039  2240.300049  1950500
# 2022-06-22  2275.389893  2214.486084  2223.260010  2240.679932  1194700
#
#               Adj Close
# Date
# 2021-06-23  2529.229980
# 2021-06-24  2545.639893
# ...

# %%
#Apple data
aapl_data=web.DataReader(name='AAPL',data_source='yahoo',start=start_date,end=end_date)
aapl_data
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2021-06-23  134.320007  133.229996  133.770004  133.699997   60214200.0
# 2021-06-24  134.639999  132.929993  134.449997  133.410004   68711000.0
# 2021-06-25  133.889999  132.809998  133.460007  133.110001   70783700.0
# 2021-06-28  135.250000  133.350006  133.410004  134.779999   62111300.0
# 2021-06-29  136.490005  134.350006  134.800003  136.330002   64556100.0
# ...                ...         ...         ...         ...          ...
# 2022-06-15  137.339996  132.160004  134.289993  135.429993   91533000.0
# 2022-06-16  132.389999  129.039993  132.080002  130.059998  108123900.0
# 2022-06-17  133.080002  129.809998  130.070007  131.559998  134118500.0
# 2022-06-21  137.059998  133.320007  133.419998  135.869995   81000500.0
# 2022-06-22  137.759995  133.910004  134.789993  135.350006   73237900.0
#
#              Adj Close
# Date
# 2021-06-23  132.940491
# 2021-06-24  132.652115
# ...

# %%
#Microsoft data
msft_data=web.DataReader(name='MSFT',data_source='yahoo',start=start_date,end=end_date)
msft_data
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-06-23  266.829987  264.429993  265.989990  265.269989  19518700.0
# 2021-06-24  267.850006  265.470001  266.160004  266.690002  21446900.0
# 2021-06-25  267.250000  264.760010  266.230011  265.019989  25611100.0
# 2021-06-28  268.899994  265.910004  266.190002  268.720001  19590000.0
# 2021-06-29  271.649994  267.980011  268.869995  271.399994  19937800.0
# ...                ...         ...         ...         ...         ...
# 2022-06-15  255.300003  246.419998  248.309998  251.759995  33111700.0
# 2022-06-16  247.419998  243.020004  245.979996  244.970001  33169200.0
# 2022-06-17  250.500000  244.029999  244.699997  247.649994  42800400.0
# 2022-06-21  254.750000  249.509995  250.259995  253.740005  29928300.0
# 2022-06-22  257.170013  250.369995  251.889999  253.130005  25939900.0
#
#              Adj Close
# Date
# 2021-06-23  263.121460
# 2021-06-24  264.529999
# 2021-06-25  262.873474
# ...

# %%
#Adding a column named company on all data-sets
amzn_data['company'] = 'Amazon'
goog_data['company'] = 'Google'
aapl_data['company'] = 'Apple'
msft_data['company'] = 'Microsoft'

# %%
#Combined Data-set
data=pd.concat([amzn_data,goog_data,aapl_data,msft_data],sort=False)
data
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-06-23  176.050003  174.160004  175.250000  175.190994  56266000.0
# 2021-06-24  176.242996  171.542496  175.382004  172.453995  76640000.0
# 2021-06-25  173.240997  169.709000  173.199997  170.072998  78820000.0
# 2021-06-28  172.399994  170.675507  170.800003  172.194504  44856000.0
# 2021-06-29  172.801498  171.151505  171.940994  172.406998  41968000.0
# ...                ...         ...         ...         ...         ...
# 2022-06-15  255.300003  246.419998  248.309998  251.759995  33111700.0
# 2022-06-16  247.419998  243.020004  245.979996  244.970001  33169200.0
# 2022-06-17  250.500000  244.029999  244.699997  247.649994  42800400.0
# 2022-06-21  254.750000  249.509995  250.259995  253.740005  29928300.0
# 2022-06-22  257.170013  250.369995  251.889999  253.130005  25939900.0
#
#              Adj Close    company
# Date
# 2021-06-23  175.190994     Amazon
# ...

# %%
#Exporting the data
data.to_csv("stock_data.csv",index=False)

# %% [markdown]
# ##Performing clean operation

# %%
#Checking for null values
data.isnull().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# company      0
# dtype: int64

# %%
#Checking for dublicate vlaues 
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##Change in stock price over time

# %%
amzn_data=amzn_data.reset_index('Date')
goog_data=goog_data.reset_index('Date')
aapl_data=aapl_data.reset_index('Date')
msft_data=msft_data.reset_index('Date')

# %%
#Displaying changes in stock over time using a line plot
plt.figure(figsize=(25,10))
plt.xlabel="Time"
plt.ylabel="Stock_Price"
plt.plot(amzn_data['Date'],amzn_data['Adj Close'],"r",label='Amazon')
plt.plot(goog_data['Date'],goog_data['Adj Close'],"b",label='Google')
plt.plot(aapl_data['Date'],aapl_data['Adj Close'],"g",label='Apple')
plt.plot(msft_data['Date'],msft_data['Adj Close'],"c",label='Microsoft')
plt.title("Stock prices ove time")
plt.legend()
plt.show()

# %%
#Scaling down the google stock prices for a good comparison
plt.figure(figsize=(25,10))
plt.xlabel="Time"
plt.ylabel="Stock_Price"
plt.plot(amzn_data['Date'],amzn_data['Adj Close'],"r",label='Amazon')
plt.plot(goog_data['Date'],goog_data['Adj Close']/10,"b",label='Google')
plt.plot(aapl_data['Date'],aapl_data['Adj Close'],"g",label='Apple')
plt.plot(msft_data['Date'],msft_data['Adj Close'],"c",label='Microsoft')
plt.title("Stock prices ove time")
plt.legend()
plt.show()

# %%
#Change in stock's volume over time for amazon
plt.figure(figsize=(25,10))
plt.xlabel="Time"
plt.ylabel="Stock_Price"
plt.plot(amzn_data['Date'],amzn_data['Volume'],"r")
plt.title("Amazon")
# Out:
# Text(0.5, 1.0, 'Amazon')

# %%
#Change in stock's volume over time for google
plt.figure(figsize=(25,10))
plt.xlabel="Time"
plt.ylabel="Stock_Price"
plt.plot(goog_data['Date'],goog_data['Volume'],"b")
plt.title("Google")
# Out:
# Text(0.5, 1.0, 'Google')

# %%
#Change in stock's volume over time for Apple
plt.figure(figsize=(25,10))
plt.xlabel="Time"
plt.ylabel="Stock_Price"
plt.plot(aapl_data['Date'],aapl_data['Volume'],"g")
plt.title("Apple")
# Out:
# Text(0.5, 1.0, 'Apple')

# %%
#Change in stock's volume over time for Microsoft
plt.figure(figsize=(25,10))
plt.xlabel="Time"
plt.ylabel="Stock_Price"
plt.plot(msft_data['Date'],msft_data['Volume'],"r")
plt.title("Microsoft")
# Out:
# Text(0.5, 1.0, 'Microsoft')

# %% [markdown]
# ##Moving average of various stocks

# %%
#Rolling mean for amazon over 20,50,100 days
amzn_data['MA for 20 Days'] = amzn_data['Adj Close'].rolling(20).mean()
amzn_data['MA for 50 Days'] = amzn_data['Adj Close'].rolling(50).mean()
amzn_data['MA for 100 Days'] = amzn_data['Adj Close'].rolling(100).mean()

# %%
amzn_data
# Out:
#           Date        High         Low        Open       Close      Volume  \
# 0   2021-06-23  176.050003  174.160004  175.250000  175.190994  56266000.0
# 1   2021-06-24  176.242996  171.542496  175.382004  172.453995  76640000.0
# 2   2021-06-25  173.240997  169.709000  173.199997  170.072998  78820000.0
# 3   2021-06-28  172.399994  170.675507  170.800003  172.194504  44856000.0
# 4   2021-06-29  172.801498  171.151505  171.940994  172.406998  41968000.0
# ..         ...         ...         ...         ...         ...         ...
# 247 2022-06-15  109.059998  103.529999  103.860001  107.669998  85011100.0
# 248 2022-06-16  104.580002  102.010002  104.470001  103.660004  82186300.0
# 249 2022-06-17  106.980003  102.510002  102.800003  106.220001  99399000.0
# 250 2022-06-21  111.629997  103.559998  108.199997  108.680000  70901200.0
# 251 2022-06-22  112.129997  107.019997  107.430000  108.949997  59942500.0
#
# ...

# %%
#Rolling mean for google over 20,50,100 days
goog_data['MA for 20 Days'] = goog_data['Adj Close'].rolling(20).mean()
goog_data['MA for 50 Days'] = goog_data['Adj Close'].rolling(50).mean()
goog_data['MA for 100 Days'] = goog_data['Adj Close'].rolling(100).mean()

# %%
goog_data
# Out:
#           Date         High          Low         Open        Close   Volume  \
# 0   2021-06-23  2555.919922  2525.040039  2531.000000  2529.229980   984700
# 1   2021-06-24  2550.709961  2539.199951  2541.070068  2545.639893   946700
# 2   2021-06-25  2550.100098  2528.879883  2539.139893  2539.899902  1674200
# 3   2021-06-28  2546.739990  2519.476074  2540.000000  2536.389893  1405500
# 4   2021-06-29  2540.000000  2508.739990  2535.449951  2520.370117  1047500
# ..         ...          ...          ...          ...          ...      ...
# 247 2022-06-15  2241.260010  2162.375000  2177.989990  2207.810059  1659600
# 248 2022-06-16  2185.810059  2115.850098  2162.989990  2132.719971  1765700
# 249 2022-06-17  2184.989990  2112.571045  2130.699951  2157.310059  2163500
# 250 2022-06-21  2253.459961  2185.870117  2194.040039  2240.300049  1950500
# 251 2022-06-22  2275.389893  2214.486084  2223.260010  2240.679932  1194700
#
# ...

# %%
#Rolling mean for apple over 20,50,100 days
aapl_data['MA for 20 Days'] = aapl_data['Adj Close'].rolling(20).mean()
aapl_data['MA for 50 Days'] = aapl_data['Adj Close'].rolling(50).mean()
aapl_data['MA for 100 Days'] = aapl_data['Adj Close'].rolling(100).mean()

# %%
aapl_data
# Out:
#           Date        High         Low        Open       Close       Volume  \
# 0   2021-06-23  134.320007  133.229996  133.770004  133.699997   60214200.0
# 1   2021-06-24  134.639999  132.929993  134.449997  133.410004   68711000.0
# 2   2021-06-25  133.889999  132.809998  133.460007  133.110001   70783700.0
# 3   2021-06-28  135.250000  133.350006  133.410004  134.779999   62111300.0
# 4   2021-06-29  136.490005  134.350006  134.800003  136.330002   64556100.0
# ..         ...         ...         ...         ...         ...          ...
# 247 2022-06-15  137.339996  132.160004  134.289993  135.429993   91533000.0
# 248 2022-06-16  132.389999  129.039993  132.080002  130.059998  108123900.0
# 249 2022-06-17  133.080002  129.809998  130.070007  131.559998  134118500.0
# 250 2022-06-21  137.059998  133.320007  133.419998  135.869995   81000500.0
# 251 2022-06-22  137.759995  133.910004  134.789993  135.350006   73237900.0
#
# ...

# %%
#Rolling mean for microsoft over 20,50,100 days
msft_data['MA for 20 Days'] = msft_data['Adj Close'].rolling(20).mean()
msft_data['MA for 50 Days'] = msft_data['Adj Close'].rolling(50).mean()
msft_data['MA for 100 Days'] = msft_data['Adj Close'].rolling(100).mean()

# %%
msft_data
# Out:
#           Date        High         Low        Open       Close      Volume  \
# 0   2021-06-23  266.829987  264.429993  265.989990  265.269989  19518700.0
# 1   2021-06-24  267.850006  265.470001  266.160004  266.690002  21446900.0
# 2   2021-06-25  267.250000  264.760010  266.230011  265.019989  25611100.0
# 3   2021-06-28  268.899994  265.910004  266.190002  268.720001  19590000.0
# 4   2021-06-29  271.649994  267.980011  268.869995  271.399994  19937800.0
# ..         ...         ...         ...         ...         ...         ...
# 247 2022-06-15  255.300003  246.419998  248.309998  251.759995  33111700.0
# 248 2022-06-16  247.419998  243.020004  245.979996  244.970001  33169200.0
# 249 2022-06-17  250.500000  244.029999  244.699997  247.649994  42800400.0
# 250 2022-06-21  254.750000  249.509995  250.259995  253.740005  29928300.0
# 251 2022-06-22  257.170013  250.369995  251.889999  253.130005  25939900.0
#
# ...

# %% [markdown]
# ##Daily Return average

# %%
amzn_data['Daily Return'] = amzn_data['Adj Close'].pct_change()
goog_data['Daily Return'] = goog_data['Adj Close'].pct_change()
aapl_data['Daily Return'] = aapl_data['Adj Close'].pct_change()
msft_data['Daily Return'] = msft_data['Adj Close'].pct_change()

# %%
amzn_data
# Out:
#           Date        High         Low        Open       Close      Volume  \
# 0   2021-06-23  176.050003  174.160004  175.250000  175.190994  56266000.0
# 1   2021-06-24  176.242996  171.542496  175.382004  172.453995  76640000.0
# 2   2021-06-25  173.240997  169.709000  173.199997  170.072998  78820000.0
# 3   2021-06-28  172.399994  170.675507  170.800003  172.194504  44856000.0
# 4   2021-06-29  172.801498  171.151505  171.940994  172.406998  41968000.0
# ..         ...         ...         ...         ...         ...         ...
# 247 2022-06-15  109.059998  103.529999  103.860001  107.669998  85011100.0
# 248 2022-06-16  104.580002  102.010002  104.470001  103.660004  82186300.0
# 249 2022-06-17  106.980003  102.510002  102.800003  106.220001  99399000.0
# 250 2022-06-21  111.629997  103.559998  108.199997  108.680000  70901200.0
# 251 2022-06-22  112.129997  107.019997  107.430000  108.949997  59942500.0
#
# ...

# %%
goog_data
# Out:
#           Date         High          Low         Open        Close   Volume  \
# 0   2021-06-23  2555.919922  2525.040039  2531.000000  2529.229980   984700
# 1   2021-06-24  2550.709961  2539.199951  2541.070068  2545.639893   946700
# 2   2021-06-25  2550.100098  2528.879883  2539.139893  2539.899902  1674200
# 3   2021-06-28  2546.739990  2519.476074  2540.000000  2536.389893  1405500
# 4   2021-06-29  2540.000000  2508.739990  2535.449951  2520.370117  1047500
# ..         ...          ...          ...          ...          ...      ...
# 247 2022-06-15  2241.260010  2162.375000  2177.989990  2207.810059  1659600
# 248 2022-06-16  2185.810059  2115.850098  2162.989990  2132.719971  1765700
# 249 2022-06-17  2184.989990  2112.571045  2130.699951  2157.310059  2163500
# 250 2022-06-21  2253.459961  2185.870117  2194.040039  2240.300049  1950500
# 251 2022-06-22  2275.389893  2214.486084  2223.260010  2240.679932  1194700
#
# ...

# %%
aapl_data
# Out:
#           Date        High         Low        Open       Close       Volume  \
# 0   2021-06-23  134.320007  133.229996  133.770004  133.699997   60214200.0
# 1   2021-06-24  134.639999  132.929993  134.449997  133.410004   68711000.0
# 2   2021-06-25  133.889999  132.809998  133.460007  133.110001   70783700.0
# 3   2021-06-28  135.250000  133.350006  133.410004  134.779999   62111300.0
# 4   2021-06-29  136.490005  134.350006  134.800003  136.330002   64556100.0
# ..         ...         ...         ...         ...         ...          ...
# 247 2022-06-15  137.339996  132.160004  134.289993  135.429993   91533000.0
# 248 2022-06-16  132.389999  129.039993  132.080002  130.059998  108123900.0
# 249 2022-06-17  133.080002  129.809998  130.070007  131.559998  134118500.0
# 250 2022-06-21  137.059998  133.320007  133.419998  135.869995   81000500.0
# 251 2022-06-22  137.759995  133.910004  134.789993  135.350006   73237900.0
#
# ...

# %%
msft_data
# Out:
#           Date        High         Low        Open       Close      Volume  \
# 0   2021-06-23  266.829987  264.429993  265.989990  265.269989  19518700.0
# 1   2021-06-24  267.850006  265.470001  266.160004  266.690002  21446900.0
# 2   2021-06-25  267.250000  264.760010  266.230011  265.019989  25611100.0
# 3   2021-06-28  268.899994  265.910004  266.190002  268.720001  19590000.0
# 4   2021-06-29  271.649994  267.980011  268.869995  271.399994  19937800.0
# ..         ...         ...         ...         ...         ...         ...
# 247 2022-06-15  255.300003  246.419998  248.309998  251.759995  33111700.0
# 248 2022-06-16  247.419998  243.020004  245.979996  244.970001  33169200.0
# 249 2022-06-17  250.500000  244.029999  244.699997  247.649994  42800400.0
# 250 2022-06-21  254.750000  249.509995  250.259995  253.740005  29928300.0
# 251 2022-06-22  257.170013  250.369995  251.889999  253.130005  25939900.0
#
# ...

# %% [markdown]
# ##Creating a trend column

# %%
#Classifying various return values
def trend(x):
  if x > -0.015 and x <= 0.015:
    return 'Slight or No change'
  elif x > 0.015 and x <= 0.04:
    return 'Slight Positive'
  elif x < -0.015 and x >= -0.4:
    return 'Slight Negative'
  elif x > 0.04 and x <= 0.06:
    return 'Positive'
  elif x < -0.04 and x >= -0.06:
    return 'Negative'
  elif x > 0.06 and x <= 0.07:
    return 'Among top gainers'
  elif x < -0.06 and x >= -0.07:
    return 'Among top losers'
  elif x > 0.07:
    return 'Bull run'
  elif x <= -0.07:
    return 'Bear drop'

# %%
amzn_data['Trend'] = amzn_data['Daily Return'].apply(lambda x: trend(x))
goog_data['Trend'] = goog_data['Daily Return'].apply(lambda x: trend(x))
aapl_data['Trend'] = aapl_data['Daily Return'].apply(lambda x: trend(x))
msft_data['Trend'] = msft_data['Daily Return'].apply(lambda x: trend(x))

# %%
amzn_data
# Out:
#           Date        High         Low        Open       Close      Volume  \
# 0   2021-06-23  176.050003  174.160004  175.250000  175.190994  56266000.0
# 1   2021-06-24  176.242996  171.542496  175.382004  172.453995  76640000.0
# 2   2021-06-25  173.240997  169.709000  173.199997  170.072998  78820000.0
# 3   2021-06-28  172.399994  170.675507  170.800003  172.194504  44856000.0
# 4   2021-06-29  172.801498  171.151505  171.940994  172.406998  41968000.0
# ..         ...         ...         ...         ...         ...         ...
# 247 2022-06-15  109.059998  103.529999  103.860001  107.669998  85011100.0
# 248 2022-06-16  104.580002  102.010002  104.470001  103.660004  82186300.0
# 249 2022-06-17  106.980003  102.510002  102.800003  106.220001  99399000.0
# 250 2022-06-21  111.629997  103.559998  108.199997  108.680000  70901200.0
# 251 2022-06-22  112.129997  107.019997  107.430000  108.949997  59942500.0
#
# ...

# %%
goog_data
# Out:
#           Date         High          Low         Open        Close   Volume  \
# 0   2021-06-23  2555.919922  2525.040039  2531.000000  2529.229980   984700
# 1   2021-06-24  2550.709961  2539.199951  2541.070068  2545.639893   946700
# 2   2021-06-25  2550.100098  2528.879883  2539.139893  2539.899902  1674200
# 3   2021-06-28  2546.739990  2519.476074  2540.000000  2536.389893  1405500
# 4   2021-06-29  2540.000000  2508.739990  2535.449951  2520.370117  1047500
# ..         ...          ...          ...          ...          ...      ...
# 247 2022-06-15  2241.260010  2162.375000  2177.989990  2207.810059  1659600
# 248 2022-06-16  2185.810059  2115.850098  2162.989990  2132.719971  1765700
# 249 2022-06-17  2184.989990  2112.571045  2130.699951  2157.310059  2163500
# 250 2022-06-21  2253.459961  2185.870117  2194.040039  2240.300049  1950500
# 251 2022-06-22  2275.389893  2214.486084  2223.260010  2240.679932  1194700
#
# ...

# %%
aapl_data
# Out:
#           Date        High         Low        Open       Close       Volume  \
# 0   2021-06-23  134.320007  133.229996  133.770004  133.699997   60214200.0
# 1   2021-06-24  134.639999  132.929993  134.449997  133.410004   68711000.0
# 2   2021-06-25  133.889999  132.809998  133.460007  133.110001   70783700.0
# 3   2021-06-28  135.250000  133.350006  133.410004  134.779999   62111300.0
# 4   2021-06-29  136.490005  134.350006  134.800003  136.330002   64556100.0
# ..         ...         ...         ...         ...         ...          ...
# 247 2022-06-15  137.339996  132.160004  134.289993  135.429993   91533000.0
# 248 2022-06-16  132.389999  129.039993  132.080002  130.059998  108123900.0
# 249 2022-06-17  133.080002  129.809998  130.070007  131.559998  134118500.0
# 250 2022-06-21  137.059998  133.320007  133.419998  135.869995   81000500.0
# 251 2022-06-22  137.759995  133.910004  134.789993  135.350006   73237900.0
#
# ...

# %%
msft_data
# Out:
#           Date        High         Low        Open       Close      Volume  \
# 0   2021-06-23  266.829987  264.429993  265.989990  265.269989  19518700.0
# 1   2021-06-24  267.850006  265.470001  266.160004  266.690002  21446900.0
# 2   2021-06-25  267.250000  264.760010  266.230011  265.019989  25611100.0
# 3   2021-06-28  268.899994  265.910004  266.190002  268.720001  19590000.0
# 4   2021-06-29  271.649994  267.980011  268.869995  271.399994  19937800.0
# ..         ...         ...         ...         ...         ...         ...
# 247 2022-06-15  255.300003  246.419998  248.309998  251.759995  33111700.0
# 248 2022-06-16  247.419998  243.020004  245.979996  244.970001  33169200.0
# 249 2022-06-17  250.500000  244.029999  244.699997  247.649994  42800400.0
# 250 2022-06-21  254.750000  249.509995  250.259995  253.740005  29928300.0
# 251 2022-06-22  257.170013  250.369995  251.889999  253.130005  25939900.0
#
# ...

# %% [markdown]
# ###Visulaizing trend frequency using pie chart

# %%
data=pd.concat([amzn_data,goog_data,aapl_data,msft_data],sort=False)
data
# Out:
#           Date        High         Low        Open       Close      Volume  \
# 0   2021-06-23  176.050003  174.160004  175.250000  175.190994  56266000.0
# 1   2021-06-24  176.242996  171.542496  175.382004  172.453995  76640000.0
# 2   2021-06-25  173.240997  169.709000  173.199997  170.072998  78820000.0
# 3   2021-06-28  172.399994  170.675507  170.800003  172.194504  44856000.0
# 4   2021-06-29  172.801498  171.151505  171.940994  172.406998  41968000.0
# ..         ...         ...         ...         ...         ...         ...
# 247 2022-06-15  255.300003  246.419998  248.309998  251.759995  33111700.0
# 248 2022-06-16  247.419998  243.020004  245.979996  244.970001  33169200.0
# 249 2022-06-17  250.500000  244.029999  244.699997  247.649994  42800400.0
# 250 2022-06-21  254.750000  249.509995  250.259995  253.740005  29928300.0
# 251 2022-06-22  257.170013  250.369995  251.889999  253.130005  25939900.0
#
# ...

# %%
set(data['Trend'])
# Out:
# {'Among top gainers',
#  'Bull run',
#  None,
#  'Positive',
#  'Slight Negative',
#  'Slight Positive',
#  'Slight or No change'}

# %%
result=data['Trend'].value_counts()
result
# Out:
# Slight or No change    608
# Slight Negative        204
# Slight Positive        168
# Positive                21
# Bull run                 2
# Among top gainers        1
# Name: Trend, dtype: int64

# %%
#Creating a pie chart
plt.figure(figsize=(20,20))
plt.pie(result.values, labels=result.index,autopct = "%1.1f%%")
plt.show()

# %% [markdown]
# ##Correaltion between daily returns of various stocks

# %%
df=pd.merge(amzn_data,goog_data,on='Date',how='left')
df=pd.merge(df,aapl_data,on='Date',how='left')
df=pd.merge(df,msft_data,on='Date',how='left')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Open_x', 'Adj Close_x', 'MA for 50 Days_x', 'MA for 20 Days_x', 'company_x', 'Close_x', 'MA for 100 Days_x', 'Trend_x', 'High_x', 'Volume_x', 'Daily Return_x', 'Low_x'} in the result is deprecated and will raise a MergeError in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df
# Out:
#           Date      High_x       Low_x      Open_x     Close_x    Volume_x  \
# 0   2021-06-23  176.050003  174.160004  175.250000  175.190994  56266000.0
# 1   2021-06-24  176.242996  171.542496  175.382004  172.453995  76640000.0
# 2   2021-06-25  173.240997  169.709000  173.199997  170.072998  78820000.0
# 3   2021-06-28  172.399994  170.675507  170.800003  172.194504  44856000.0
# 4   2021-06-29  172.801498  171.151505  171.940994  172.406998  41968000.0
# ..         ...         ...         ...         ...         ...         ...
# 247 2022-06-15  109.059998  103.529999  103.860001  107.669998  85011100.0
# 248 2022-06-16  104.580002  102.010002  104.470001  103.660004  82186300.0
# 249 2022-06-17  106.980003  102.510002  102.800003  106.220001  99399000.0
# 250 2022-06-21  111.629997  103.559998  108.199997  108.680000  70901200.0
# 251 2022-06-22  112.129997  107.019997  107.430000  108.949997  59942500.0
#
# ...

# %%
df=df.filter(like='Adj Close')
df
# Out:
#      Adj Close_x  Adj Close_y  Adj Close_x  Adj Close_y
# 0     175.190994  2529.229980   132.940491   263.121460
# 1     172.453995  2545.639893   132.652115   264.529999
# 2     170.072998  2539.899902   132.353836   262.873474
# 3     172.194504  2536.389893   134.014343   266.543549
# 4     172.406998  2520.370117   135.555527   269.201843
# ..           ...          ...          ...          ...
# 247   107.669998  2207.810059   135.429993   251.759995
# 248   103.660004  2132.719971   130.059998   244.970001
# 249   106.220001  2157.310059   131.559998   247.649994
# 250   108.680000  2240.300049   135.869995   253.740005
# 251   108.949997  2240.679932   135.350006   253.130005
#
# [252 rows x 4 columns]

# %%
df.columns=['Amazon','Google','Apple','Microsoft']
df
# Out:
#          Amazon       Google       Apple   Microsoft
# 0    175.190994  2529.229980  132.940491  263.121460
# 1    172.453995  2545.639893  132.652115  264.529999
# 2    170.072998  2539.899902  132.353836  262.873474
# 3    172.194504  2536.389893  134.014343  266.543549
# 4    172.406998  2520.370117  135.555527  269.201843
# ..          ...          ...         ...         ...
# 247  107.669998  2207.810059  135.429993  251.759995
# 248  103.660004  2132.719971  130.059998  244.970001
# 249  106.220001  2157.310059  131.559998  247.649994
# 250  108.680000  2240.300049  135.869995  253.740005
# 251  108.949997  2240.679932  135.350006  253.130005
#
# [252 rows x 4 columns]

# %%
#Relationship between stock of various companies
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot = True)
