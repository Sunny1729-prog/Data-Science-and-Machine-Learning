# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunny1729-prog/Data-Science-and-Machine-Learning/blob/main/%24_Class_5_6(DS_%26_ML).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #pd.Series

# %%
df=pd.Series(data=[433,341,652,132,363],index=["Marketing","Finance","Advertisement","Human_resource","Sales"],name="Departments")
df
# Out:
# Marketing         433
# Finance           341
# Advertisement     652
# Human_resource    132
# Sales             363
# Name: Departments, dtype: int64

# %%
type(df)
# Out:
# pandas.core.series.Series

# %%
df.values
# Out:
# array([433, 341, 652, 132, 363])

# %%
df.index
# Out:
# Index(['Marketing', 'Finance', 'Advertisement', 'Human_resource', 'Sales'], dtype='object')

# %%
df.name
# Out:
# 'Departments'

# %%
df.loc["Advertisement"]
# Out:
# 652

# %%
df.loc["Finance"]
# Out:
# 341

# %%
df.iloc[0]
# Out:
# 433

# %%
df.iloc[4]
# Out:
# 363

# %%
#index parameter is not necessary, by default 0,1,2,3,4,5,6,...
#name is also not necessary
ser=pd.Series(data=[433,341,652,132,363])
ser
# Out:
# 0    433
# 1    341
# 2    652
# 3    132
# 4    363
# dtype: int64

# %%
df.dtype
# Out:
# dtype('int64')

# %% [markdown]
# #pd.DataFrame

# %%
table=np.linspace(80,99,9,dtype='int64').reshape(3,3)
table
# Out:
# array([[80, 82, 84],
#        [87, 89, 91],
#        [94, 96, 99]])

# %%
#A single column can contain multiple datatypes but it is unnecessary

df=pd.DataFrame(data=table[::-1],index=['First','Second','Third'],columns=['Maths','Physics','Chemistry'])
df
# Out:
#         Maths  Physics  Chemistry
# First      94       96         99
# Second     87       89         91
# Third      80       82         84

# %%
df.columns
# Out:
# Index(['Maths', 'Physics', 'Chemistry'], dtype='object')

# %%
df.index
# Out:
# Index(['First', 'Second', 'Third'], dtype='object')

# %%
df.dtypes     # Notice 'dtypes' not 'dtype' since there are multiple columns.
# Out:
# Maths        int64
# Physics      int64
# Chemistry    int64
# dtype: object

# %%
df.shape
# Out:
# (3, 3)

# %%
#Selecting columns

a=df['Physics']
a
# Out:
# First     96
# Second    89
# Third     82
# Name: Physics, dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
b=df[['Physics','Chemistry']]
b
# Out:
#         Physics  Chemistry
# First        96         99
# Second       89         91
# Third        82         84

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc['Second','Chemistry']
# Out:
# 91

# %%
df.iloc[1,1] #[row,column]
# Out:
# 89

# %%
# !wget https://raw.githubusercontent.com/nachikethmurthy/Source-Code-Dataset-for-Machine-Learning-using-Python/main/Data/IPL%20IMB381IPL2013.csv
# Out:
# --2022-05-14 15:32:58--  https://raw.githubusercontent.com/nachikethmurthy/Source-Code-Dataset-for-Machine-Learning-using-Python/main/Data/IPL%20IMB381IPL2013.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15661 (15K) [text/plain]
# Saving to: ‘IPL IMB381IPL2013.csv’
#
# IPL IMB381IPL2013.c 100%[===================>]  15.29K  --.-KB/s    in 0s
#
# 2022-05-14 15:32:58 (64.0 MB/s) - ‘IPL IMB381IPL2013.csv’ saved [15661/15661]

# %%
#Reading from a csv,excel file

df=pd.read_csv('/content/IPL IMB381IPL2013.csv')
#pd.read_excel('file_path')
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
df.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=130, step=1)

# %%
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df.head(10)
# Out:
#    Sl.NO.    PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1    Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2   Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3    Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4      Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5   Badrinath, S    2     IND   CSK      Batsman      63       0
# 5       6     Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 6       7      Balaji, L    2     IND  CSK+       Bowler      51      27
# 7       8  Bollinger, DE    2     AUS   CSK       Bowler      54      50
# 8       9       Botha, J    2      SA    RR   Allrounder      83      17
# 9      10    Boucher, MV    2      SA  RCB+    W. Keeper    5515       1
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# ...

# %%
df.tail()
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 125           0      0.00  ...  125.64       2       0     0    0.00  0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00  0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74  7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43  7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50  9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df.tail(10)
# Out:
#      Sl.NO.     PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 120     121     Vettori, DL    2      NZ    DD+   Allrounder    4486     359
# 121     122  Vinay Kumar, R    2     IND   RCB+       Bowler      11       1
# 122     123       Warne, SK    3     AUS     RR       Bowler    3154     708
# 123     124      Warner, DA    1     AUS     DD      Batsman     483       2
# 124     125       White, CL    2     AUS   RCB+      Batsman     146       5
# 125     126       Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127     Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128    Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129     Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130      Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# ...

# %%
df.dtypes
# Out:
# Sl.NO.             int64
# PLAYER NAME       object
# AGE                int64
# COUNTRY           object
# TEAM              object
# PLAYING ROLE      object
# T-RUNS             int64
# T-WKTS             int64
# ODI-RUNS-S         int64
# ODI-SR-B         float64
# ODI-WKTS           int64
# ODI-SR-BL        float64
# CAPTAINCY EXP      int64
# RUNS-S             int64
# HS                 int64
# AVE              float64
# SR-B             float64
# SIXERS             int64
# RUNS-C             int64
# WKTS               int64
# AVE-BL           float64
# ECON             float64
# SR-BL            float64
# AUCTION YEAR       int64
# BASE PRICE         int64
# SOLD PRICE         int64
# dtype: object

# %%
df.shape
# Out:
# (130, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
#Exporting as xlsx(excel)

df.to_excel("export.xlsx",index=False)

# %%
#Exporting as xlsx(excel)

df.to_csv("export.csv",index=False)

# %%
df['SOLD PRICE'][df['SOLD PRICE'] > 1000000]
# Out:
# 15     1500000
# 23     1550000
# 50     1800000
# 83     1550000
# 93     1800000
# 108    1350000
# 111    1800000
# 113    1600000
# 127    1800000
# Name: SOLD PRICE, dtype: int64

# %%
df[(df['SOLD PRICE'] > 1000000) & (df['PLAYING ROLE'] == 'Batsman')]
# Out:
#      Sl.NO.    PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 50       51       Kohli, V    1     IND    RCB      Batsman     491       0
# 83       84  Pietersen, KP    2     ENG   RCB+      Batsman    6654       5
# 93       94      Sehwag, V    2     IND     DD      Batsman    8178      40
# 111     112  Tendulkar, SR    3     IND     MI      Batsman   15470      45
# 113     114     Tiwary, SS    1     IND    MI+      Batsman       0       0
# 127     128   Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 50         3590     86.31  ...  119.29      49     345     4   86.25   8.84
# 83         4184     86.76  ...  141.20      30     215     7   30.71   7.41
# 93         8090    104.68  ...  167.32      79     226     6   37.67  10.56
# 111       18426     86.23  ...  119.22      24      58     0    0.00   9.67
# ...

# %%
df[(df['SOLD PRICE'] > 1000000) & (df['PLAYING ROLE'] == 'Allrounder')]
# Out:
#      Sl.NO.  PLAYER NAME  AGE COUNTRY TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 23       24  Flintoff, A    2     ENG  CSK   Allrounder    3845     226
# 108     109   Symonds, A    3     AUS  DC+   Allrounder    1462      24
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 23         3394     88.82  ...  116.98       2     105     2    52.5  9.55
# 108        5088     92.44  ...  129.87      41     674    20    33.7  7.70
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 23   33.00          2009      950000     1550000
# 108  26.35          2008      250000     1350000
#
# [2 rows x 26 columns]

# %%
df['PLAYING ROLE'].value_counts()
# Out:
# Bowler        44
# Batsman       39
# Allrounder    35
# W. Keeper     12
# Name: PLAYING ROLE, dtype: int64

# %%
df['PLAYING ROLE'].value_counts(normalize=True)
# Out:
# Bowler        0.338462
# Batsman       0.300000
# Allrounder    0.269231
# W. Keeper     0.092308
# Name: PLAYING ROLE, dtype: float64

# %%
df[['SOLD PRICE','PLAYING ROLE']].groupby(['PLAYING ROLE']).describe()
# Out:
#              SOLD PRICE                                                    \
#                   count           mean            std       min       25%
# PLAYING ROLE
# Allrounder         35.0  519571.428571  395874.630014   20000.0  167500.0
# Batsman            39.0  647435.897436  522229.370602   50000.0  275000.0
# Bowler             44.0  419977.272727  259807.217315   24000.0  200000.0
# W. Keeper          12.0  487083.333333  389378.632820  100000.0  240000.0
#
#
#                    50%       75%        max
# PLAYING ROLE
# Allrounder    500000.0  800000.0  1550000.0
# Batsman       500000.0  750000.0  1800000.0
# Bowler        362500.0  606250.0   950000.0
# W. Keeper     387500.0  700000.0  1500000.0

# %%
#Adding a new column

df['PREMIUM']=df['SOLD PRICE']-df['BASE PRICE']
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  SR-BL  \
# 0           0      0.00  ...       0     307    15   20.47   8.90  13.93
# 1         657     71.41  ...       0      29     0    0.00  14.50   0.00
# 2        1269     80.62  ...       5    1059    29   36.52   8.81  24.90
# 3         241     84.56  ...       0    1125    49   22.96   6.23  22.14
# 4          79     45.93  ...      28       0     0    0.00   0.00   0.00
#
#    AUCTION YEAR  BASE PRICE  SOLD PRICE  PREMIUM
# ...

# %%
#Setting a column of dataframe as index

df=df.set_index('Sl.NO.')
df.head()
# Out:
#          PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# Sl.NO.
# 1        Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 2       Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 3        Agarkar, AB    2     IND   KKR       Bowler     571      58
# 4          Ashwin, R    1     IND   CSK       Bowler     284      31
# 5       Badrinath, S    2     IND   CSK      Batsman      63       0
#
#         ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ...  SIXERS  RUNS-C  WKTS  AVE-BL  \
# Sl.NO.                                  ...
# 1                0      0.00         0  ...       0     307    15   20.47
# 2              657     71.41       185  ...       0      29     0    0.00
# 3             1269     80.62       288  ...       5    1059    29   36.52
# 4              241     84.56        51  ...       0    1125    49   22.96
# 5               79     45.93         0  ...      28       0     0    0.00
#
# ...

# %%
#Resetting  the index as default i.e range(1,no. of records,1)column of dataframe as index

df=df.reset_index('Sl.NO.')
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  SR-BL  \
# 0           0      0.00  ...       0     307    15   20.47   8.90  13.93
# 1         657     71.41  ...       0      29     0    0.00  14.50   0.00
# 2        1269     80.62  ...       5    1059    29   36.52   8.81  24.90
# 3         241     84.56  ...       0    1125    49   22.96   6.23  22.14
# 4          79     45.93  ...      28       0     0    0.00   0.00   0.00
#
#    AUCTION YEAR  BASE PRICE  SOLD PRICE  PREMIUM
# ...

# %%
df2=df[['PLAYER NAME', 'TEAM', 'BASE PRICE','SOLD PRICE','PREMIUM']]
df2
# Out:
#       PLAYER NAME   TEAM  BASE PRICE  SOLD PRICE  PREMIUM
# 0     Abdulla, YA   KXIP       50000       50000        0
# 1    Abdur Razzak    RCB       50000       50000        0
# 2     Agarkar, AB    KKR      200000      350000   150000
# 3       Ashwin, R    CSK      100000      850000   750000
# 4    Badrinath, S    CSK      100000      800000   700000
# ..            ...    ...         ...         ...      ...
# 125     Yadav, AS     DC       50000      750000   700000
# 126   Younis Khan     RR      225000      225000        0
# 127  Yuvraj Singh  KXIP+      400000     1800000  1400000
# 128   Zaheer Khan    MI+      200000      450000   250000
# 129    Zoysa, DNT     DC      100000      110000    10000
#
# [130 rows x 5 columns]

# %%
df2.sort_values(by='SOLD PRICE',ascending=False).head(10)
# Out:
#        PLAYER NAME   TEAM  BASE PRICE  SOLD PRICE  PREMIUM
# 93       Sehwag, V     DD      400000     1800000  1400000
# 127   Yuvraj Singh  KXIP+      400000     1800000  1400000
# 50        Kohli, V    RCB      150000     1800000  1650000
# 111  Tendulkar, SR     MI      400000     1800000  1400000
# 113     Tiwary, SS    MI+      100000     1600000  1500000
# 83   Pietersen, KP   RCB+     1350000     1550000   200000
# 23     Flintoff, A    CSK      950000     1550000   600000
# 15       Dhoni, MS    CSK      400000     1500000  1100000
# 108     Symonds, A    DC+      250000     1350000  1100000
# 110   Taylor, LRPL   RCB+      400000     1000000   600000

# %%
df.drop(columns=['AVE-BL'], axis=1,inplace=True)  # axis 1 means columns and axis 0 means rows, inplace writes the changes in the dataframe.
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS   ECON  SR-BL  \
# 0           0      0.00  ...    0.00       0     307    15   8.90  13.93
# 1         657     71.41  ...    0.00       0      29     0  14.50   0.00
# 2        1269     80.62  ...  121.01       5    1059    29   8.81  24.90
# 3         241     84.56  ...   76.32       0    1125    49   6.23  22.14
# 4          79     45.93  ...  120.71      28       0     0   0.00   0.00
#
#    AUCTION YEAR  BASE PRICE  SOLD PRICE  PREMIUM
# ...

# %%
df.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE', 'SOLD PRICE',
#        'PREMIUM'],
#       dtype='object')

# %%
df.drop(columns=['T-RUNS'], axis=1,inplace=True)  # axis 1 means columns and axis 0 means rows, inplace writes the changes in the dataframe.

# %%
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman       0
# ..      ...           ...  ...     ...    ...          ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0
# 126     127   Younis Khan    2     PAK     RR      Batsman       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler      64
#
#      ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ...    SR-B  SIXERS  RUNS-C  WKTS   ECON  \
# 0             0      0.00         0  ...    0.00       0     307    15   8.90
# ...

# %%
#Droping a record

df.drop(labels=['ECON'],axis='columns',inplace=True)
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman       0
# ..      ...           ...  ...     ...    ...          ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0
# 126     127   Younis Khan    2     PAK     RR      Batsman       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler      64
#
#      ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ...    AVE    SR-B  SIXERS  RUNS-C  WKTS  \
# 0             0      0.00         0  ...   0.00    0.00       0     307    15
# ...

# %%
df['TEAM'].unique()
# Out:
# array(['KXIP', 'RCB', 'KKR', 'CSK', 'CSK+', 'RR', 'RCB+', 'MI+', 'DD+',
#        'KKR+', 'DC', 'MI', 'DC+', 'RR+', 'KXIP+', 'KXI+', 'DD'],
#       dtype=object)

# %%
df['TEAM'].value_counts()
# Out:
# CSK      14
# RCB+     12
# KKR+     12
# DD+      10
# DC+      10
# RR+       9
# RCB       9
# DC        7
# KXIP+     7
# MI        6
# DD        6
# MI+       6
# RR        6
# CSK+      5
# KKR       5
# KXIP      5
# KXI+      1
# Name: TEAM, dtype: int64

# %%
TEAM_C={'RCB':'RCB', 'KKR':'KKR', 'CSK':'CSK', 'CSK+':'CSK', 'RR':'RR', 'RCB+':'RCB', 'MI+':'MI', 'KXIP':'KXIP', 'DD+':'DD',
       'KKR+':'KKR', 'DC':'DC', 'MI':'MI', 'DC+':'DC', 'RR+':'RR', 'KXIP+':'KXI', 'KXI+':'KXI', 'DD':'DD'}
TEAM_C
# Out:
# {'CSK': 'CSK',
#  'CSK+': 'CSK',
#  'DC': 'DC',
#  'DC+': 'DC',
#  'DD': 'DD',
#  'DD+': 'DD',
#  'KKR': 'KKR',
#  'KKR+': 'KKR',
#  'KXI+': 'KXI',
#  'KXIP': 'KXIP',
#  'KXIP+': 'KXI',
#  'MI': 'MI',
#  'MI+': 'MI',
#  'RCB': 'RCB',
#  'RCB+': 'RCB',
#  'RR': 'RR',
#  'RR+': 'RR'}

# %%
df['TEAM'] = df['TEAM'].map(TEAM_C)
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-WKTS  ODI-RUNS-S  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0           0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler      18         657
# 2       3   Agarkar, AB    2     IND   KKR       Bowler      58        1269
# 3       4     Ashwin, R    1     IND   CSK       Bowler      31         241
# 4       5  Badrinath, S    2     IND   CSK      Batsman       0          79
#
#    ODI-SR-B  ODI-WKTS  ...    AVE    SR-B  SIXERS  RUNS-C  WKTS  SR-BL  \
# 0      0.00         0  ...   0.00    0.00       0     307    15  13.93
# 1     71.41       185  ...   0.00    0.00       0      29     0   0.00
# 2     80.62       288  ...  18.56  121.01       5    1059    29  24.90
# 3     84.56        51  ...   5.80   76.32       0    1125    49  22.14
# 4     45.93         0  ...  32.93  120.71      28       0     0   0.00
#
#    AUCTION YEAR  BASE PRICE  SOLD PRICE  PREMIUM
# ...

# %%
df['TEAM'].value_counts()
# Out:
# RCB     21
# CSK     19
# KKR     17
# DC      17
# DD      16
# RR      15
# MI      12
# KXI      8
# KXIP     5
# Name: TEAM, dtype: int64

# %% [markdown]
# ###Merge

# %%
df1=pd.DataFrame({'Student_name':['Sam','Jordan'],'Maths':[88,89],'Physics':[91,92]})
df2=pd.DataFrame({'Student_name':['Michael','Gill'],'Maths':[88,85],'Chemistry':[98,96]})

# %%
display(df1)
display(df2)
# Out:
#   Student_name  Maths  Physics
# 0          Sam     88       91
# 1       Jordan     89       92
#   Student_name  Maths  Chemistry
# 0      Michael     88         98
# 1         Gill     85         96

# %%
# MERGE
# NaN denotes 'Not a Number'
df3=pd.merge(df1,df2,on='Student_name',how='outer')
df3
# Out:
#   Student_name  Maths_x  Physics  Maths_y  Chemistry
# 0          Sam     88.0     91.0      NaN        NaN
# 1       Jordan     89.0     92.0      NaN        NaN
# 2      Michael      NaN      NaN     88.0       98.0
# 3         Gill      NaN      NaN     85.0       96.0

# %%
df4=pd.merge(df1,df2,on=['Student_name','Maths'],how='outer')
df4
# Out:
#   Student_name  Maths  Physics  Chemistry
# 0          Sam     88     91.0        NaN
# 1       Jordan     89     92.0        NaN
# 2      Michael     88      NaN       98.0
# 3         Gill     85      NaN       96.0

# %%
df5=df4[['Student_name','Physics']][not(pd.isna(df4['Physics']))] #selecting columns and applying condition at same time
df5
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-aa205d902278> in <module>()
# ----> 1 df5=df4[['Student_name','Physics']][not(pd.isna(df4['Physics']))] #selecting columns and applying condition at same time
#       2 df5
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1536     def __nonzero__(self):
#    1537         raise ValueError(
# -> 1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1540         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df4.rename(columns={'Student_name':'Student'},inplace=True)
df4
# Out:
#    Student  Maths  Physics  Chemistry
# 0      Sam     88     91.0        NaN
# 1   Jordan     89     92.0        NaN
# 2  Michael     88      NaN       98.0
# 3     Gill     85      NaN       96.0

# %%
#Change axis

df4.T
# Out:
#               0       1        2     3
# Student     Sam  Jordan  Michael  Gill
# Maths        88      89       88    85
# Physics    91.0    92.0      NaN   NaN
# Chemistry   NaN     NaN     98.0  96.0

# %%
# !wget https://raw.githubusercontent.com/nachikethmurthy/Source-Code-Dataset-for-Machine-Learning-using-Python/main/titanic_dataset.csv
# Out:
# --2022-05-14 15:34:09--  https://raw.githubusercontent.com/nachikethmurthy/Source-Code-Dataset-for-Machine-Learning-using-Python/main/titanic_dataset.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61194 (60K) [text/plain]
# Saving to: ‘titanic_dataset.csv’
#
# titanic_dataset.csv 100%[===================>]  59.76K  --.-KB/s    in 0.008s
#
# 2022-05-14 15:34:09 (7.71 MB/s) - ‘titanic_dataset.csv’ saved [61194/61194]

# %%
df6=pd.read_csv('/content/titanic_dataset.csv')
df6.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df6.set_index('PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df6['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df6.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df6
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#How many male and female survived(only display survived)
#df7=df6[['Sex','Survived']]
df6[df6['Survived'] == 1].groupby('Sex')['Survived'].value_counts()
# Out:
# Sex     Survived
# female  1           233
# male    1           109
# Name: Survived, dtype: int64

# %%
df6['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df6[df6['Survived'] == 0].groupby('Sex')['Survived'].value_counts()
# Out:
# Sex     Survived
# female  0            81
# male    0           468
# Name: Survived, dtype: int64
